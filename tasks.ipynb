# %% [markdown]
# # Webtoon Content Performance and User Engagement Analysis

# %% [markdown]
# #### Name: Tanmay Prasad Mallick
# #### Date: 10-10-2024

# %% [markdown]
# ## Task-1: Engagement Trends for "Why is the Tower of God Show So Popular?"
#
# ## Overview
# This report analyzes user engagement metrics for the article titled "Why is the Tower of God Show So Popular?" by Nandini Goswami, published on September 13, 2024. By examining page views and time spent on different sections of the article, we aim to identify trends in user engagement and suggest strategies to enhance the average time spent on the page.
#
# ## User Data Overview
#
# ### Page Views Over Time
# The article experienced varied levels of page views throughout the week, as depicted in the following data:
#
# | Day    | Page Views |
# |--------|------------|
# | Day 1  | 120        |
# | Day 2  | 200        |
# | Day 3  | 150        |
# | Day 4  | 220        |
# | Day 5  | 180        |
# | Day 6  | 170        |
# | Day 7  | 210        |
#
# ### Time Spent on Article Sections
# The percentage of time spent by users on different sections of the article is as follows:
#
# | Section                      | Time Spent (%) |
# |------------------------------|----------------|
# | Intro                        | 15             |
# | Tower of God Overview        | 25             |
# | Korean Narrative             | 20             |
# | Character Design             | 18             |
# | Season 2 Update             | 10             |
# | Similar Anime                | 12             |

# %% [markdown]
# ## Visualizations
#
# ### Page Views Over Time (Bar Graph)
# The bar graph below illustrates the number of page views over the week. Notably, **Day 4** witnessed the highest number of views, indicating a significant interest in the article, potentially driven by external factors such as social media engagement or content releases.
#
# ### Time Spent on Article Sections (Pie Chart)
# The pie chart below shows the distribution of time spent on different sections of the article. The **Tower of God Overview** section captured the most attention (25%), while the **Season 2 Update** section attracted the least interest (10%).

# %%
import matplotlib.pyplot as plt

# Mock data for page views over time (days)
days = ['Day 1', 'Day 2', 'Day 3', 'Day 4', 'Day 5', 'Day 6', 'Day 7']
page_views = [120, 200, 150, 220, 180, 170, 210]

# Mock data for time spent on different sections of the article
sections = ['Intro', 'Tower of God Overview', 'Korean Narrative', 'Character Design', 'Season 2 Update', 'Similar Anime']
time_spent = [15, 25, 20, 18, 10, 12]  # in percentage

# Create subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Bar Graph: Page Views over time
ax1.bar(days, page_views, color='skyblue')
ax1.set_title('Page Views Over Time')
ax1.set_xlabel('Days')
ax1.set_ylabel('Page Views')

# Pie Chart: Time spent on sections
ax2.pie(time_spent, labels=sections, autopct='%1.1f%%', startangle=140, colors=['lightcoral', 'gold', 'lightgreen', 'skyblue', 'plum', 'peachpuff'])
ax2.set_title('Time Spent on Article Sections')

# Show plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Analysis and Recommendations
#
# ### Engagement Trends
# The analysis of the user data reveals key insights:
# - The spike in page views on **Day 4** suggests a peak in interest, warranting further investigation into potential factors that contributed to this increase.
# - The **Tower of God Overview** section's popularity indicates that users are particularly interested in understanding the main themes and characters of the series.
#
# ### Strategies to Increase Average Time Spent on the Page
#
# 1. **Enhance Interactive Content:**
#    - Implement interactive elements such as polls, quizzes, or discussion prompts related to the article's key themes. For example, users could vote on their favorite character or make predictions about the upcoming plot developments. This engagement can lead to increased time spent on the page as readers explore and interact with the content.
#
# 2. **Add Multimedia Elements:**
#    - Incorporate multimedia components, including videos, GIFs, or infographics that provide additional insights or summarize key points. For instance, a video analyzing Bam’s character development or an infographic comparing character designs can enrich the reading experience and encourage users to linger on the page longer.
#
# ## Conclusion
# This report identifies engagement trends in the article "Why is the Tower of God Show So Popular?" through an analysis of page views and time spent across different sections. By implementing interactive and multimedia content strategies, there is potential to significantly increase the average time users spend on the page, thereby enhancing overall user engagement.

# %% [markdown]
# ## Task-2: User Interaction Data for “Refund High School Chapter 22-30”
#
#
# ## Overview
# The article titled “Refund High School Chapter 22-30: The New Arc of Mook” presents a continuation of the storyline, featuring character developments and new plot twists. Given the assumed user interaction metrics, there is an opportunity to enhance engagement through strategic content changes.
#
# ## Assumed User Interaction Metrics
# Based on hypothetical data, the current engagement metrics are as follows:
# - **Bounce Rate:** 40%
# - **Average Time Spent:** 2.5 minutes
# - **Click-Through Rate (CTR):** 5%
# These metrics indicate that while some readers are engaged, there is a significant drop-off, suggesting a need for improvement in content delivery.
#
# ## Proposed A/B Testing Strategy
# To evaluate the effectiveness of different content approaches, we recommend conducting A/B tests with the following variations:
#
# ### Variations
# 1. **Control Group:** Original Article
# - The baseline performance of the original article is represented by the assumed metrics mentioned above.
#
# 2. **Variation A:** New Headline
# - Example Headline: **“Unraveling the Mystery: What Lies Ahead for Aru, Gunn, and Mook in Refund High School?”**
# - Rationale: A compelling headline can significantly influence user interest and encourage clicks.
#
# 3. **Variation B:** New Visuals
# - **Content Changes:** Include visually appealing images, character illustrations, and infographics summarizing key plot points.
# - **Rationale**: Engaging visuals can improve user retention and encourage exploration of the article's content.
#
# ### Goals for A/B Testing
# - **Bounce Rate:** Aim to reduce the bounce rate from the assumed 40% to a target of 35% for Variation A and 30% for Variation B.
# - **Average Time Spent:** Increase the average time spent on the page from 2.5 minutes to 3.0 minutes for Variation A and 3.5 minutes for Variation B.
# - **CTR:** Enhance the CTR from 5% to 7% for Variation A and 9% for Variation B.

# %% [markdown]
# ### Visualization

# %%
import numpy as np

# Mock data for A/B testing results
# Assuming we have 1000 users for each variation
users = 1000

# Control Group (Original Article)
control_bounce_rate = 40  # percentage
control_avg_time_spent = 2.5  # in minutes
control_ctr = 5  # percentage

# Variation A (New Headline)
variation_a_bounce_rate = 35
variation_a_avg_time_spent = 3.0
variation_a_ctr = 7

# Variation B (New Visuals)
variation_b_bounce_rate = 30
variation_b_avg_time_spent = 3.5
variation_b_ctr = 9

# Creating an array for visualization
bounce_rates = [control_bounce_rate, variation_a_bounce_rate, variation_b_bounce_rate]
avg_time_spent = [control_avg_time_spent, variation_a_avg_time_spent, variation_b_avg_time_spent]
ctr = [control_ctr, variation_a_ctr, variation_b_ctr]

labels = ['Control', 'Variation A', 'Variation B']

# Create subplots
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Bar Graph: Bounce Rate
axs[0].bar(labels, bounce_rates, color='salmon')
axs[0].set_title('Bounce Rate Comparison')
axs[0].set_ylabel('Bounce Rate (%)')
axs[0].set_ylim(0, 50)

# Bar Graph: Average Time Spent
axs[1].bar(labels, avg_time_spent, color='lightblue')
axs[1].set_title('Average Time Spent Comparison')
axs[1].set_ylabel('Average Time Spent (minutes)')
axs[1].set_ylim(0, 5)

# Bar Graph: Click-through Rate (CTR)
axs[2].bar(labels, ctr, color='lightgreen')
axs[2].set_title('Click-through Rate Comparison')
axs[2].set_ylabel('Click-through Rate (%)')
axs[2].set_ylim(0, 15)

# Show plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Content Changes to Test
# ### Variation A: New Headline
# - **Proposed Changes:**
#     - Craft a more engaging and descriptive headline.
#     - Use subheadings and bullet points to organize content clearly, making it easier for readers to digest information.
# Variation B: New Visuals
# - **Proposed Changes:**
#     - Integrate high-quality images related to key characters and events in the story.
#     - Add infographics that highlight major plot points and character relationships, visually summarizing the narrative for quick comprehension.
#
# ## Implementation Plan
# - **Testing Duration:** Conduct the A/B tests over a two-week period to gather sufficient data for analysis.
# - **Key Metrics:** Monitor bounce rates, average time spent on the page, CTR, and user feedback through surveys.
# - **Analysis and Reporting:** Compare performance metrics between the control and variations to identify which content changes drive better engagement.
#
# ### Conclusion
# The analysis highlights potential areas for improving user engagement with the article “Refund High School Chapter 22-30: The New Arc of Mook.” By employing A/B testing strategies that focus on headline optimization and visual enhancements, we can gain valuable insights into user preferences and improve overall interaction metrics.

# %% [markdown]
# ## Task-3: User Segmentation for “11 Best Solo Leveling Arcs in the Manhwa to Read Now”
#
# ## Introduction
# The article “11 Best Solo Leveling Arcs in the Manhwa to Read Now” delves into the key arcs of the popular manhwa Solo Leveling. To optimize content delivery and improve user engagement, it's essential to understand the audience's demographics and behavior. This report outlines user segmentation based on age group and gender and provides recommendations for tailoring content to these segments.
# Mock Data for User Demographics and Behavior Segmentation
# The following mock data illustrates the assumed user demographics based on age group and gender:
#
# ## Demographics
# - **Age Groups:**
#     - Teens (13-19): 600 users
#     - Young Adults (20-29): 300 users
#     - Adults (30+): 100 users
# - **Gender Distribution:**
#     - Male: 700 users
#     - Female: 300 users
#
# ## Visual Representation
# - **Bar Chart:** User Demographics by Age Group
# - **Pie Chart:** User Distribution by Gender

# %%
import matplotlib.pyplot as plt

# Mock data for user demographics and behavior segmentation
# Demographics by age group and gender
age_groups = ['Teens (13-19)', 'Young Adults (20-29)', 'Adults (30+)']
gender_distribution = ['Male', 'Female']

# Number of users in each demographic (mock data)
user_distribution_age = [600, 300, 100]  # Assume total 1000 users
user_distribution_gender = [700, 300]     # Assume total 1000 users

# Create subplots
fig, axs = plt.subplots(1, 2, figsize=(14, 6))

# Bar Chart: User Demographics by Age Group
axs[0].bar(age_groups, user_distribution_age, color='lightblue')
axs[0].set_title('User Demographics by Age Group')
axs[0].set_ylabel('Number of Users')
axs[0].set_ylim(0, 800)

# Pie Chart: User Distribution by Gender
axs[1].pie(user_distribution_gender, labels=gender_distribution, autopct='%1.1f%%', startangle=90, colors=['salmon', 'lightgreen'])
axs[1].set_title('User Distribution by Gender')

# Show plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Analysis of User Segmentation
# 1. ### Age Group Segmentation
# - **Teens (13-19):**
#   - Representing the largest demographic, this group is likely drawn to the action-packed and fantasy elements of Solo Leveling.
#   - Content Suggestions:
#        - Utilize vibrant visuals and dynamic language to enhance engagement.
#        - Incorporate interactive elements such as polls or quizzes related to the arcs to foster community interaction.
# - **Young Adults (20-29):**
#     - This segment appreciates deeper character development and plot intricacies.
#     - Content Suggestions:
#         - Provide more in-depth analyses of character arcs and themes.
#         - Include discussions or recommendations for related series that cater to mature storytelling preferences.
# - **Adults (30+):**
#     - This group may have nostalgic ties to the manhwa genre and looks for substantial narrative depth.
#     - Content Suggestions:
#         - Highlight overarching themes of perseverance and personal growth within the arcs.
#         - Offer retrospective content that connects Solo Leveling to other significant works in the genre.
#
# 2. ### Gender Distribution
# - **Male (70%):**
#     - This group may predominantly favor action and battle sequences in the arcs.
#     - Content Suggestions:
#         - Emphasize action-oriented summaries and highlight battles in the arcs.
#         - Consider hosting live discussions or watch parties for adaptations or fan art.
# - **Female (30%):**
#     - Female readers may resonate with character relationships and emotional depth.
#     - Content Suggestions:
#         - Focus on character development, relationships, and emotional moments in the arcs.
#         - Incorporate more content that celebrates female characters and their roles in the story.
#
#
# ## Conclusion
# By segmenting the audience based on age and gender, tailored content can significantly enhance user engagement with the article “11 Best Solo Leveling Arcs in the Manhwa to Read Now.” Utilizing targeted content strategies for different demographics will foster a more inclusive and engaging environment, ultimately driving higher interaction rates and reader satisfaction.
